# %%
from IPython.display import Image

# %%
PATH = '../data/Crowdfunding/'

# %% [markdown]
# # Fonte de dados confiaveis mais atualizada:
# https://www.jbs.cam.ac.uk/wp-content/uploads/2021/06/ccaf-2021-06-report-2nd-global-alternative-finance-benchmarking-study-report.pdf

# %%
Image(PATH + 'CF_types.png')

# %% [markdown]
# # Tamanho global
#
# * Market size em 2020, excluindo a China: USD 113bi
# * Principais players: Gust, Crowdfunder, RocketHub, FirstGiving, Teespring, DonorsChoose.org, CircleUp, GiveForward, Fundable, YouCaring, IFunding, GoFundMe, Patreon, CrowdRise, Kiva, Kickstarter, Causes, FundRazr, Indiegogo

# %%
Image(PATH + 'CF_size-growth.png')

# %%
Image(PATH + 'CF_global_players.png')

# %%
Image(PATH + 'CF_vol-by-cat.png')

# %% [markdown]
# # Tamanho Brasil
#
# * 60% da LAC, de 9% do mercado global. (5.4% do mercado global)
# * Principais players brasileiros: csv (cadastrados na CVM, maioria fundos), APOIA.se, Benfeitoria, Catarse, Kickante, Padrim, Bicharia, Entropia Coletiva
# * Principais players estrangeiros no Brasil: Patreon, Kickstarter, Indiegogo

# %%
Image(PATH + 'CF_vol-by-model-BR.png')

# %% [markdown]
# # Perspectiva de crescimento no Brasil
#
# * Na parte de lending, há uma perspectiva de crescimento - mesmo que não explosivo. Essa modalidae, no Brasil, é feita por empresas brasileiras para clientes brasileiros, não necessitando de pagamentos x-border.
# * Na parte de crowdfunding per se, a série histórica demonstra na melhor das hipóteses uma estagnação em um volume já bem baixo.
