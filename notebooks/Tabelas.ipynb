# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(17, 9)})

# %%
df = pd.read_csv('../data/dados_preliminares.csv', )

# %%
df
# Out:
#        segmento  tamanho_global_bilhoes  tamanho_brasil_bilhoes  cagr  \
# 0        Gaming                   214.2                    2.30  12.9
# 1       Apostas                    57.5                    1.30  11.7
# 2    e-Learning                   215.0                    2.70  13.0
# 3       Turismo                     8.6                    0.85   7.8
# 4    e-Commerce                 16000.0                   25.30  14.7
# 5   Remittance*                    17.9                    4.90  15.0
# 6          Gig*                   297.0                   -1.00  15.0
# 7  Crowdfunding                   113.0                    4.10  11.8
#
#    tamanho_global_2030_est  tamanho_brasil_2030_est
# 0               565.419786                 6.071268
# 1               139.345590                 3.150422
# 2               571.565501                 7.177799
# 3                15.683700                 1.550133
# 4             47932.195927                75.792785
# ...

# %% [markdown]
# # Comparação tamanho global

# %%
graph = sns.barplot(x=df['segmento'], y=df['tamanho_global_bilhoes'])
graph.set(ylim=(0, 500));
